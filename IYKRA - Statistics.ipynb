# %% [markdown]
# # 1. Import Package

# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 100


import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Load Data

# %%
df = pd.read_csv('Seasons_Stats.csv')

# %%
df
# Out:
#        Unnamed: 0    Year             Player  Pos   Age   Tm     G    GS  \
# 0               0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN
# ...           ...     ...                ...  ...   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller   PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller    C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman    C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser   SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac    C  19.0  LAL  38.0  11.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ## 3.1 Filtering Data

# %%
df_17 = df[df['Year']==2017.0]

# %%
df_17
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24096       24096  2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0
# 24097       24097  2017.0         Quincy Acy  PF  26.0  TOT  38.0   1.0
# 24098       24098  2017.0         Quincy Acy  PF  26.0  DAL   6.0   0.0
# 24099       24099  2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0
# 24100       24100  2017.0       Steven Adams   C  23.0  OKC  80.0  80.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %% [markdown]
# ## 3.2 Drop Duplicate data
#
# Dibagian ini, data duplikat berdasarkan "PLAYER" akan diremove dan akan dihasilkan data yang paling TerUPDATE

# %%
df_17.drop_duplicates(subset='Player', keep="last", inplace=True)
# Out:
# <ipython-input-91-dd840fcbb221>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_17.drop_duplicates(subset='Player', keep="last", inplace=True)

# %%
df_17
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24096       24096  2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0
# 24099       24099  2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0
# 24100       24100  2017.0       Steven Adams   C  23.0  OKC  80.0  80.0
# 24101       24101  2017.0      Arron Afflalo  SG  31.0  SAC  61.0  45.0
# 24102       24102  2017.0      Alexis Ajinca   C  28.0  NOP  39.0  15.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %% [markdown]
# ## 3.3 Check Missing Value

# %%
sns.heatmap(df_17.isna())
plt.show()

# %% [markdown]
# Dari gambar di atas, terlihat ada beberapa fitur yang memiliki "Missing Value" bahkan ada fitur yang seluruhnya "Missing Value"

# %% [markdown]
# Dibagian ini akan dilihat berapa persentase Missing Value di tiap-tiap fiturnya

# %%
df_2017 = pd.DataFrame(df_17.isna().sum()/len(df_17)*100)
df_2017
# Out:
#                      0
# Unnamed: 0    0.000000
# Year          0.000000
# Player        0.000000
# Pos           0.000000
# Age           0.000000
# Tm            0.000000
# G             0.000000
# GS            0.000000
# MP            0.000000
# PER           0.000000
# TS%           0.411523
# 3PAr          0.411523
# FTr           0.411523
# ORB%          0.000000
# DRB%          0.000000
# TRB%          0.000000
# AST%          0.000000
# STL%          0.000000
# BLK%          0.000000
# TOV%          0.411523
# USG%          0.000000
# blanl       100.000000
# OWS           0.000000
# DWS           0.000000
# WS            0.000000
# WS/48         0.000000
# blank2      100.000000
# OBPM          0.000000
# DBPM          0.000000
# BPM           0.000000
# VORP          0.000000
# FG            0.000000
# FGA           0.000000
# FG%           0.411523
# 3P            0.000000
# 3PA           0.000000
# 3P%           8.024691
# 2P            0.000000
# 2PA           0.000000
# ...

# %% [markdown]
# ### 3.3.1 Drop fitur yang memiliki missing Value >= 50%

# %%
hapus_kolom = []
for i in df_2017[df_2017[0]>=50].reset_index()['index']:
    hapus_kolom.append(i)

# %%
hapus_kolom
# Out:
# ['blanl', 'blank2']

# %%
df_17.drop(['blanl', 'blank2'], axis=1, inplace=True)
# Out:
# c:\users\asus\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_17
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24096       24096  2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0
# 24099       24099  2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0
# 24100       24100  2017.0       Steven Adams   C  23.0  OKC  80.0  80.0
# 24101       24101  2017.0      Arron Afflalo  SG  31.0  SAC  61.0  45.0
# 24102       24102  2017.0      Alexis Ajinca   C  28.0  NOP  39.0  15.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %% [markdown]
# ### 3.3.2 cek missing value and Imputing data numerical dengan 0

# %%
df_numerics_only = df_17.select_dtypes(include=np.number)
df_numerics_only
# Out:
#        Unnamed: 0    Year   Age     G    GS      MP   PER    TS%   3PAr  \
# 24096       24096  2017.0  23.0  68.0   6.0  1055.0  10.1  0.560  0.724
# 24099       24099  2017.0  26.0  32.0   1.0   510.0  13.1  0.587  0.542
# 24100       24100  2017.0  23.0  80.0  80.0  2389.0  16.5  0.589  0.002
# 24101       24101  2017.0  31.0  61.0  45.0  1580.0   9.0  0.559  0.360
# 24102       24102  2017.0  28.0  39.0  15.0   584.0  12.9  0.529  0.022
# ...           ...     ...   ...   ...   ...     ...   ...    ...    ...
# 24686       24686  2017.0  24.0  62.0  58.0  1725.0  16.7  0.604  0.002
# 24687       24687  2017.0  27.0  51.0   5.0   525.0  13.0  0.508  0.006
# 24688       24688  2017.0  20.0  19.0   0.0   108.0   7.3  0.346  0.000
# 24689       24689  2017.0  22.0  44.0  18.0   843.0   6.9  0.503  0.448
# 24690       24690  2017.0  19.0  38.0  11.0   609.0  17.0  0.547  0.013
#
#          FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS   WS  \
# ...

# %%
df_numeric_missing = pd.DataFrame(df_numerics_only.isna().sum()/len(df_numerics_only)*100)
df_numeric_missing
# Out:
#                    0
# Unnamed: 0  0.000000
# Year        0.000000
# Age         0.000000
# G           0.000000
# GS          0.000000
# MP          0.000000
# PER         0.000000
# TS%         0.411523
# 3PAr        0.411523
# FTr         0.411523
# ORB%        0.000000
# DRB%        0.000000
# TRB%        0.000000
# AST%        0.000000
# STL%        0.000000
# BLK%        0.000000
# TOV%        0.411523
# USG%        0.000000
# OWS         0.000000
# DWS         0.000000
# WS          0.000000
# WS/48       0.000000
# OBPM        0.000000
# DBPM        0.000000
# BPM         0.000000
# VORP        0.000000
# FG          0.000000
# FGA         0.000000
# FG%         0.411523
# 3P          0.000000
# 3PA         0.000000
# 3P%         8.024691
# 2P          0.000000
# 2PA         0.000000
# 2P%         0.823045
# eFG%        0.411523
# FT          0.000000
# FTA         0.000000
# FT%         3.703704
# ORB         0.000000
# DRB         0.000000
# TRB         0.000000
# ...

# %%
hapus_kolom = []
for i in df_numeric_missing[df_numeric_missing[0] > 0].reset_index()['index']:
    hapus_kolom.append(i)

# %%
hapus_kolom
# Out:
# ['TS%', '3PAr', 'FTr', 'TOV%', 'FG%', '3P%', '2P%', 'eFG%', 'FT%']

# %%
imp_num = SimpleImputer(strategy='constant', fill_value=0)
df_17[hapus_kolom] = imp_num.fit_transform(df_17[hapus_kolom]) 
df_17
# Out:
# <ipython-input-103-c0157a68b5a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_17[hapus_kolom] = imp_num.fit_transform(df_17[hapus_kolom])
# c:\users\asus\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# ...

# %% [markdown]
# ### 3.3.3 Cek missing value and imputing data categorical dengan "-"

# %%
df_categorics_only = df_17.select_dtypes(exclude=np.number)
df_categorics_only
# Out:
#                   Player Pos   Tm
# 24096       Alex Abrines  SG  OKC
# 24099         Quincy Acy  PF  BRK
# 24100       Steven Adams   C  OKC
# 24101      Arron Afflalo  SG  SAC
# 24102      Alexis Ajinca   C  NOP
# ...                  ...  ..  ...
# 24686        Cody Zeller  PF  CHO
# 24687       Tyler Zeller   C  BOS
# 24688  Stephen Zimmerman   C  ORL
# 24689        Paul Zipser  SF  CHI
# 24690        Ivica Zubac   C  LAL
#
# [486 rows x 3 columns]

# %%
df_categoric_missing = pd.DataFrame(df_categorics_only.isna().sum()/len(df_categorics_only)*100)
df_categoric_missing
# Out:
#           0
# Player  0.0
# Pos     0.0
# Tm      0.0

# %% [markdown]
# Berdasarkan informasi di atas, pada fitur Kategorik sudah tidak terdapat Missing Value

# %%
df_17  # Data sudah bersih
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24096       24096  2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0
# 24099       24099  2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0
# 24100       24100  2017.0       Steven Adams   C  23.0  OKC  80.0  80.0
# 24101       24101  2017.0      Arron Afflalo  SG  31.0  SAC  61.0  45.0
# 24102       24102  2017.0      Alexis Ajinca   C  28.0  NOP  39.0  15.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %% [markdown]
# # Nomer 1

# %% [markdown]
# **Ini adalah daftar Player yang paling muda dari setiap tim**

# %%
df_17.groupby(by=['Tm']).min().reset_index()[['Tm', 'Player', 'Age']].sort_values(by=['Age']).reset_index().drop() # daftar pemain yang paling muda untuk setiap tim
# Out:
#     index   Tm            Player   Age
# 0      16  MIL       Gary Payton  19.0
# 1      25  SAC  Anthony Tolliver  19.0
# 2      23  PHO     Alan Williams  19.0
# 3       7  DEN        Alonzo Gee  19.0
# 4      13  LAL    Brandon Ingram  19.0
# 5      12  LAC     Alan Anderson  19.0
# 6      14  MEM   Andrew Harrison  20.0
# 7      18  NOP     Alexis Ajinca  20.0
# 8      17  MIN     Adreian Payne  20.0
# 9      15  MIA      Dion Waiters  20.0
# 10     11  IND      Aaron Brooks  20.0
# 11     10  HOU       Bobby Brown  20.0
# 12      9  GSW  Anderson Varejao  20.0
# 13      8  DET    Andre Drummond  20.0
# 14     26  SAS       Bryn Forbes  20.0
# 15      1  BOS        Al Horford  20.0
# 16     21  ORL      Aaron Gordon  20.0
# 17     20  OKC      Alex Abrines  20.0
# 18     22  PHI    Alex Poythress  21.0
# 19     24  POR   Al-Farouq Aminu  21.0
# 20     27  TOR     Bruno Caboclo  21.0
# 21     29  WAS  Bojan Bogdanovic  21.0
# 22     28  UTA        Alec Burks  21.0
# ...

# %% [markdown]
# **Ini adalah daftar Player yang paling tuaa dari setiap tim**

# %%
df_17.groupby(by=['Tm']).max().reset_index()[['Tm', 'Player', 'Age']].sort_values(by=['Age']).reset_index() #daftar pemain yang paling tua untuk setiap tim
# Out:
#     index   Tm                   Player   Age
# 0      24  POR           Tim Quarterman  28.0
# 1       1  BOS             Tyler Zeller  31.0
# 2      27  TOR              Serge Ibaka  31.0
# 3       4  CHO           Treveon Graham  31.0
# 4      25  SAC      Willie Cauley-Stein  31.0
# 5      29  WAS               Trey Burke  32.0
# 6      19  NYK        Willy Hernangomez  32.0
# 7      21  ORL            Terrence Ross  32.0
# 8      22  PHI  Timothe Luwawu-Cabarrot  32.0
# 9      11  IND           Thaddeus Young  32.0
# 10     18  NOP              Tim Frazier  33.0
# 11      8  DET            Tobias Harris  34.0
# 12     23  PHO           Tyson Chandler  34.0
# 13     10  HOU            Troy Williams  34.0
# 14     17  MIN              Zach LaVine  34.0
# 15     28  UTA               Trey Lyles  35.0
# 16      3  CHI              Robin Lopez  35.0
# 17     20  OKC           Victor Oladipo  36.0
# 18      0  ATL             Tim Hardaway  36.0
# ...

# %% [markdown]
# # Nomer 2

# %% [markdown]
# **Ini adalah daftar Player yang memiliki Minute played terbanyak dari setiap posisinya**

# %%
df_17.groupby(by=['Pos']).max()[['Player','MP']]
# Out:
#               Player      MP
# Pos
# C      Zaza Pachulia  3030.0
# PF     Zach Randolph  2803.0
# PG      Yogi Ferrell  2947.0
# SF   Wilson Chandler  3048.0
# SG       Zach LaVine  2796.0

# %% [markdown]
# # Nomer 3

# %% [markdown]
# **Ini adalah TIM dengan rata-rata total rebound percentage paling tinggi**

# %%
df_17.groupby(by=['Tm']).mean()[['TRB%']].sort_values(by=['TRB%'], ascending=False).head(1)
# Out:
#           TRB%
# Tm
# WAS  12.735294

# %% [markdown]
# **Ini adalah TIM dengan rata-rata Assist percentage paling tinggi**

# %%
df_17.groupby(by=['Tm']).mean()[['AST%']].sort_values(by=['AST%'], ascending=False).head(1)
# Out:
#           AST%
# Tm
# DEN  15.723529

# %% [markdown]
# **Ini adalah TIM dengan rata-rata Steal Percentage paling tinggi**

# %%
df_17.groupby(by=['Tm']).mean()[['STL%']].sort_values(by=['STL%'], ascending=False).head(1)
# Out:
#          STL%
# Tm
# MIN  2.413333

# %% [markdown]
# **Ini adalah TIM dengan rata-rata Blocks paling tinggi**

# %%
df_17.groupby(by=['Tm']).mean()[['BLK%']].sort_values(by=['BLK%'], ascending=False).head(1)
# Out:
#          BLK%
# Tm
# MIL  2.741176

# %% [markdown]
# # Nomer 4

# %%
df_17[df_17['PTS']==df_17['PTS'].max()]
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24654       24654  2017.0  Russell Westbrook  PG  28.0  OKC  81.0  81.0
#
#            MP   PER    TS%  3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# 24654  2802.0  30.6  0.554   0.3  0.433   5.4  28.8  17.1  57.3   2.3   0.9
#
#        TOV%  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP     FG  \
# 24654  15.9  41.7  8.5  4.6  13.1  0.224  10.9   4.7  15.6  12.4  824.0
#
#           FGA    FG%     3P    3PA    3P%     2P     2PA    2P%   eFG%     FT  \
# 24654  1941.0  0.425  200.0  583.0  0.343  624.0  1358.0  0.459  0.476  710.0
#
#          FTA    FT%    ORB    DRB    TRB    AST    STL   BLK    TOV     PF  \
# 24654  840.0  0.845  137.0  727.0  864.0  840.0  133.0  31.0  438.0  190.0
#
#           PTS
# 24654  2558.0

# %% [markdown]
# **Di musim 2017 berdasarkan point yang dibuat, menurut saya yang layak menjadi Sang Superstar adalah Bapak Russell Westbrook**

# %% [markdown]
# # Nomer 5

# %%
df_17.groupby(by=['Tm']).mean()[['PER']].sort_values(by=['PER'], ascending=False).head(1)
# Out:
#            PER
# Tm
# DEN  15.294118

# %% [markdown]
# **Di musim 2017 berdasarkan rata-rata PER(Player efficiency Rating) Tim "DEN" berhasil menjadi tim terbaik.**
